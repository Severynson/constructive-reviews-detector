# %%
import pandas as pd

# %%
df = pd.read_csv("../data/tripadvisor_reviews.csv", delimiter="|")

# %%
df.columns
# Out:
# Index(['location_id', 'location_title', 'location_url', 'review_id', 'rating',
#        'published_date', 'title', 'text', 'language', 'review_url',
#        'user_name', 'trip_type', 'travel_date', 'helpful_votes'],
#       dtype='object')

# %%
df.iloc[0]
# Out:
# location_id                                                  513544
# location_title                     Arroyo's Mexican Cafe (Stockton)
# location_url      https://www.tripadvisor.com/Restaurant_Review-...
# review_id                                                 928522578
# rating                                                            1
# published_date                                 2023-12-05T19:15:39Z
# title                                              Cheap and skimpy
# text              Do not waste your time coming here. They tend ...
# language                                                         en
# review_url        https://www.tripadvisor.com/ShowUserReviews-g3...
# user_name                                                   897teeg
# trip_type                                               Solo travel
# travel_date                                              2023-12-31
# helpful_votes                                                   1.0
# ...

# %%
df.iloc[0,7]
# Out:
# "Do not waste your time coming here. They tend to be very skimpy when it comes to your food. I paid for two beef, cheese & rice burritos which the cook put about 5 pieces of rice in each burrito! I called to speak with the manager and he said it was a mistake (yeah right) and that he wouldn't charge me for rice on my next order! He should've been offering two new burritos, if that's the best you can do, I will not be back! Also, they limit you on the salsa to go, you only get one per burrito and it's only a teaspoon.  Terrible and cheap! Try other places that believe in giving you your money's worth."

# %%
df.head(5)
# Out:
#    location_id                    location_title  \
# 0       513544  Arroyo's Mexican Cafe (Stockton)
# 1       513544  Arroyo's Mexican Cafe (Stockton)
# 2       513544  Arroyo's Mexican Cafe (Stockton)
# 3       513544  Arroyo's Mexican Cafe (Stockton)
# 4       513544  Arroyo's Mexican Cafe (Stockton)
#
#                                         location_url  review_id  rating  \
# 0  https://www.tripadvisor.com/Restaurant_Review-...  928522578       1
# 1  https://www.tripadvisor.com/Restaurant_Review-...  832672314       3
# 2  https://www.tripadvisor.com/Restaurant_Review-...  831662454       4
# 3  https://www.tripadvisor.com/Restaurant_Review-...  749503268       3
# 4  https://www.tripadvisor.com/Restaurant_Review-...  653951321       5
#
#          published_date                                      title  \
# 0  2023-12-05T19:15:39Z                           Cheap and skimpy
# 1  2022-03-28T18:41:31Z                     Nice Place with a View
# ...

# %%
df.isnull().sum()
# Out:
# location_id         0
# location_title      0
# location_url        0
# review_id           0
# rating              0
# published_date      0
# title               2
# text                0
# language            0
# review_url          0
# user_name           0
# trip_type           0
# travel_date         0
# helpful_votes     839
# dtype: int64

# %%
df["text"].count()
# Out:
# np.int64(1011)

# %%
df["text"].nunique()
# Out:
# 566
